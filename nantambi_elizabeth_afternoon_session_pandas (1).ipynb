# %%
import pandas as pd 
df= pd.DataFrame()
print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
dataset={'cars':["tesla","Jeep"], 'year_of_make':["2022","2023"]}
dframe=pd.DataFrame(dataset)
print(dframe)
print(dataset['cars'][1])
# Out:
#     cars year_of_make
# 0  tesla         2022
# 1   Jeep         2023
# Jeep

# %%
list=["Liz","Ariella","Isaac"]
df2=pd.Series(list)
print(df2)
# Out:
# 0        Liz
# 1    Ariella
# 2      Isaac
# dtype: object

# %%
# Dictionary with days and dates
data = {'Monday': '2023-07-03',
        'Tuesday': '2023-07-04',
        'Wednesday': '2023-07-05',
        'Thursday': '2023-07-06',
        'Friday': '2023-07-07'}

# Create a pandas Series
series = pd.Series(data)

print(series)
# Out:
# Monday       2023-07-03
# Tuesday      2023-07-04
# Wednesday    2023-07-05
# Thursday     2023-07-06
# Friday       2023-07-07
# dtype: object

# %%
#printing out only data for monday and Tuesday
print(series[['Monday','Tuesday']])
# Out:
# Monday     2023-07-03
# Tuesday    2023-07-04
# dtype: object

# %%
work = pd.read_csv('C:\\Users\\Liz\\Desktop\\Recess\\Exercise Python\\Exercise Python\\Work.csv')

# %%
work.head()
# Out:
#      Name         city  age py-score
# 0    Emma      Kampala   23       90
# 1  Wilber        Mbale   26       75
# 2   Robin         Gulu   25     mine
# 3   Tevor  Livingstone  NaN       89
# 4    Yeko       Tororo   20       94

# %%
work.tail()
# Out:
#      Name         city    age py-score
# 2   Robin         Gulu     25     mine
# 3   Tevor  Livingstone    NaN       89
# 4    Yeko       Tororo     20       94
# 5  Miriam         Arua  Train      NaN
# 6   Jesca      Mbarara     21       84

# %%
work.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      7 non-null      object
#  1   city      7 non-null      object
#  2   age       6 non-null      object
#  3   py-score  6 non-null      object
# dtypes: object(4)
# memory usage: 352.0+ bytes

# %%
work.dropna()
# Out:
#      Name     city age py-score
# 0    Emma  Kampala  23       90
# 1  Wilber    Mbale  26       75
# 2   Robin     Gulu  25     mine
# 4    Yeko   Tororo  20       94
# 6   Jesca  Mbarara  21       84

# %%
work.fillna("value")
# Out:
#      Name         city    age py-score
# 0    Emma      Kampala     23       90
# 1  Wilber        Mbale     26       75
# 2   Robin         Gulu     25     mine
# 3   Tevor  Livingstone  value       89
# 4    Yeko       Tororo     20       94
# 5  Miriam         Arua  Train    value
# 6   Jesca      Mbarara     21       84

# %%
df=pd.DataFrame(work)
print(df)
# Out:
#      Name         city    age py-score
# 0    Emma      Kampala     23       90
# 1  Wilber        Mbale     26       75
# 2   Robin         Gulu     25     mine
# 3   Tevor  Livingstone    NaN       89
# 4    Yeko       Tororo     20       94
# 5  Miriam         Arua  Train      NaN
# 6   Jesca      Mbarara     21       84

# %%
mine = pd.read_csv('C:\\Users\\Liz\\Desktop\\Recess\\Exercise Python\\Exercise Python\\mine.csv')

# %%
# Identify and remove rows with wrong data based on a condition
df = mine[mine['calories'] > 0]

# Display the cleaned dataset
print(df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'calories'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
work = work[pd.to_numeric(work['py-score'], errors='coerce').notnull()] 
work
# Out:
#      Name         city  age py-score
# 0    Emma      Kampala   23       90
# 1  Wilber        Mbale   26       75
# 3   Tevor  Livingstone  NaN       89
# 4    Yeko       Tororo   20       94
# 6   Jesca      Mbarara   21       84

# %%
work = work[pd.to_numeric(work['age'], errors='coerce').notnull()] 
work
# Out:
#      Name     city age py-score
# 0    Emma  Kampala  23       90
# 1  Wilber    Mbale  26       75
# 4    Yeko   Tororo  20       94
# 6   Jesca  Mbarara  21       84

# %%
#mine

# %%
mine = mine.loc[pd.to_numeric(mine['Duration'], errors='coerce').notnull()] 
mine = mine.loc[pd.to_numeric(mine['Pulse'], errors='coerce').notnull()] 
mine = mine.loc[pd.to_numeric(mine['Maxpulse'], errors='coerce').notnull()] 
mine = mine.loc[pd.to_numeric(mine['Calories'], errors='coerce').notnull()] 
mine
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [164 rows x 4 columns]

# %%
#Remove duplicates from mine
mine.drop_duplicates()
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [157 rows x 4 columns]

# %%
#perform colerration
mine.corr(method='spearman')
# Out:
#           Duration     Pulse  Maxpulse  Calories
# Duration  1.000000 -0.167986 -0.072278  0.815127
# Pulse    -0.167986  1.000000  0.787362  0.186022
# Maxpulse -0.072278  0.787362  1.000000  0.271928
# Calories  0.815127  0.186022  0.271928  1.000000
